# %%
# perfect code
import numpy as np
import cv2
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, Flatten, Dense, 
                                     Reshape, Activation, Dropout)
from sklearn.model_selection import train_test_split

# -------------------------------
# 1. Define Character Set and Parameters
# -------------------------------
# Allowed characters: A-Z, a-z, 0-9 (62 total)
char_set = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789"
num_classes = len(char_set)
char_to_index = {char: idx for idx, char in enumerate(char_set)}
index_to_char = {idx: char for char, idx in char_to_index.items()}

# Expected CAPTCHA length (modify as needed)
max_length = 5  

# -------------------------------
# 2. Data Loading and Preprocessing
# -------------------------------
def load_data(data_dir):
    X, y = [], []
    for file in os.listdir(data_dir):
        if file.lower().endswith((".jpg", ".png", ".jpeg")):
            img_path = os.path.join(data_dir, file)
            # Read in grayscale and resize to 100x50 (width x height)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, (100, 50))
            X.append(img)
            # Use the source file name (without extension) as the label
            y.append(os.path.splitext(file)[0])
    return np.array(X), np.array(y)

def encode_labels(labels, max_length):
    """
    One-hot encode labels into shape (samples, max_length, num_classes)
    """
    encoded = np.zeros((len(labels), max_length, num_classes))
    for i, label in enumerate(labels):
        # For each character in the label, set the corresponding index to 1.
        for j, char in enumerate(label):
            encoded[i, j, char_to_index[char]] = 1
    return encoded

# Set your dataset folder path here
data_dir = rf"C:\Users\hp\OneDrive\Desktop\Python Software\Dataset\samples"  
X, y = load_data(data_dir)

# Normalize images to the range [0, 1] and add a channel dimension.
X = X.astype(np.float32) / 255.0
X = X.reshape(-1, 50, 100, 1)

# One-hot encode the labels
y_encoded = encode_labels(y, max_length)

# Split data into training and test sets.
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# -------------------------------
# 3. Build an Improved CNN Model
# -------------------------------
# Note: Instead of applying softmax in the Dense layer (which would compute a single
# softmax over all outputs), we use a Dense layer with linear activation, reshape, 
# and then apply an Activation('softmax') which works independently along the last axis.
model = Sequential([
    # Convolutional layers
    Conv2D(32, (3, 3), activation="relu", input_shape=(50, 100, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    Flatten(),
    Dense(256, activation="relu"),
    Dropout(0.5),
    # The Dense layer outputs max_length*num_classes values.
    Dense(max_length * num_classes, activation="linear"),
    # Reshape the flat output into (max_length, num_classes)
    Reshape((max_length, num_classes)),
    # Apply softmax along the last dimension so that each character position
    # gets its own probability distribution over the 62 classes.
    Activation("softmax")
])

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.summary()

# -------------------------------
# 4. Train and Save the Model
# -------------------------------
# You can experiment with a higher number of epochs if needed.
model.fit(X_train, y_train, epochs=50, batch_size=40, validation_data=(X_test, y_test))
model.save("captcha_model_improved.keras")
print("Training completed and model saved.")

# -------------------------------
# 5. Load the Model and Define Prediction Function
# -------------------------------
# Load the saved model
model = load_model("captcha_model_improved.keras")
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

def predict_captcha(image_path):
    # Load and preprocess the image
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (100, 50))
    img = img.astype(np.float32) / 255.0
    img = img.reshape(1, 50, 100, 1)
    # Get predictions from the model
    predictions = model.predict(img)
    # For each character position, choose the class with the highest probability
    predicted_text = "".join(index_to_char[np.argmax(prob)] for prob in predictions[0])
    return predicted_text

# -------------------------------
# 6. Test the Prediction Function
# -------------------------------
# Replace the following path with your test CAPTCHA image source (downloaded from a source URL, for example)
captcha_image = r"C:\Users\hp\OneDrive\Desktop\Python Software\2b827.png"
result = predict_captcha(captcha_image)
print("Predicted CAPTCHA:", result)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 48, 98, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 24, 49, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 22, 47, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 11, 23, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 11, 23, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 16192)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 256)                 │       4,145,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 310)                 │          79,670 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape_2 (Reshape)                  │ (None, 5, 62)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 5, 62)               │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,243,894 (16.19 MB)
#  Trainable params: 4,243,894 (16.19 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 37s 552ms/step - accuracy: 0.0513 - loss: 3.8640 - val_accuracy: 0.0972 - val_loss: 3.1428
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 477ms/step - accuracy: 0.0836 - loss: 3.1872 - val_accuracy: 0.1150 - val_loss: 2.8787
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 395ms/step - accuracy: 0.1104 - loss: 2.9444 - val_accuracy: 0.2533 - val_loss: 2.6644
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 412ms/step - accuracy: 0.2203 - loss: 2.5934 - val_accuracy: 0.3364 - val_loss: 2.3777
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 383ms/step - accuracy: 0.3259 - loss: 2.2623 - val_accuracy: 0.4654 - val_loss: 2.0091
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 417ms/step - accuracy: 0.3969 - loss: 2.0154 - val_accuracy: 0.5411 - val_loss: 1.7754
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 406ms/step - accuracy: 0.4414 - loss: 1.8116 - val_accuracy: 0.5748 - val_loss: 1.6437
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 436ms/step - accuracy: 0.4996 - loss: 1.6232 - val_accuracy: 0.6019 - val_loss: 1.5198
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 413ms/step - accuracy: 0.5359 - loss: 1.4817 - val_accuracy: 0.6336 - val_loss: 1.3929
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 425ms/step - accuracy: 0.5685 - loss: 1.3798 - val_accuracy: 0.6570 - val_loss: 1.3199
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 532ms/step - accuracy: 0.5823 - loss: 1.2871 - val_accuracy: 0.6626 - val_loss: 1.2253
# Epoch 12/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 485ms/step - accuracy: 0.6034 - loss: 1.2363 - val_accuracy: 0.6832 - val_loss: 1.1360
# Epoch 13/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 21s 491ms/step - accuracy: 0.6415 - loss: 1.1101 - val_accuracy: 0.7047 - val_loss: 1.1046
# Epoch 14/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 22s 532ms/step - accuracy: 0.6409 - loss: 1.0893 - val_accuracy: 0.7065 - val_loss: 1.0645
# Epoch 15/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 420ms/step - accuracy: 0.6531 - loss: 1.0672 - val_accuracy: 0.7084 - val_loss: 1.0457
# Epoch 16/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 417ms/step - accuracy: 0.6796 - loss: 0.9805 - val_accuracy: 0.7084 - val_loss: 1.0199
# Epoch 17/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 557ms/step - accuracy: 0.6698 - loss: 0.9700 - val_accuracy: 0.7243 - val_loss: 0.9841
# Epoch 18/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 500ms/step - accuracy: 0.6629 - loss: 0.9939 - val_accuracy: 0.7393 - val_loss: 0.9407
# Epoch 19/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 21s 489ms/step - accuracy: 0.6830 - loss: 0.9656 - val_accuracy: 0.7421 - val_loss: 0.9484
# Epoch 20/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 437ms/step - accuracy: 0.7035 - loss: 0.8751 - val_accuracy: 0.7439 - val_loss: 0.9122
# Epoch 21/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - accuracy: 0.7099 - loss: 0.8723 - val_accuracy: 0.7411 - val_loss: 0.8979
# Epoch 22/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 411ms/step - accuracy: 0.7134 - loss: 0.8635 - val_accuracy: 0.7393 - val_loss: 0.8942
# Epoch 23/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 507ms/step - accuracy: 0.7217 - loss: 0.8154 - val_accuracy: 0.7439 - val_loss: 0.9180
# Epoch 24/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 21s 505ms/step - accuracy: 0.7230 - loss: 0.8134 - val_accuracy: 0.7421 - val_loss: 0.8628
# Epoch 25/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 18s 386ms/step - accuracy: 0.7237 - loss: 0.8094 - val_accuracy: 0.7607 - val_loss: 0.8774
# Epoch 26/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 425ms/step - accuracy: 0.7276 - loss: 0.8100 - val_accuracy: 0.7570 - val_loss: 0.8461
# Epoch 27/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 411ms/step - accuracy: 0.7486 - loss: 0.7361 - val_accuracy: 0.7636 - val_loss: 0.8400
# Epoch 28/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 558ms/step - accuracy: 0.7575 - loss: 0.7288 - val_accuracy: 0.7505 - val_loss: 0.8722
# Epoch 29/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 436ms/step - accuracy: 0.7513 - loss: 0.7337 - val_accuracy: 0.7579 - val_loss: 0.8126
# Epoch 30/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 412ms/step - accuracy: 0.7570 - loss: 0.7196 - val_accuracy: 0.7579 - val_loss: 0.8406
# Epoch 31/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 465ms/step - accuracy: 0.7495 - loss: 0.7290 - val_accuracy: 0.7664 - val_loss: 0.8376
# Epoch 32/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 488ms/step - accuracy: 0.7643 - loss: 0.6690 - val_accuracy: 0.7495 - val_loss: 0.8390
# Epoch 33/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 392ms/step - accuracy: 0.7566 - loss: 0.7032 - val_accuracy: 0.7701 - val_loss: 0.7953
# Epoch 34/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 440ms/step - accuracy: 0.7757 - loss: 0.6519 - val_accuracy: 0.7720 - val_loss: 0.8136
# Epoch 35/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - accuracy: 0.7688 - loss: 0.6595 - val_accuracy: 0.7813 - val_loss: 0.8114
# Epoch 36/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 421ms/step - accuracy: 0.7866 - loss: 0.6331 - val_accuracy: 0.7607 - val_loss: 0.8389
# Epoch 37/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 399ms/step - accuracy: 0.7651 - loss: 0.6717 - val_accuracy: 0.7710 - val_loss: 0.8057
# Epoch 38/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 401ms/step - accuracy: 0.7788 - loss: 0.6310 - val_accuracy: 0.7692 - val_loss: 0.8124
# Epoch 39/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 400ms/step - accuracy: 0.7699 - loss: 0.6645 - val_accuracy: 0.7701 - val_loss: 0.8267
# Epoch 40/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 378ms/step - accuracy: 0.7867 - loss: 0.6351 - val_accuracy: 0.7654 - val_loss: 0.8226
# Epoch 41/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 474ms/step - accuracy: 0.7791 - loss: 0.6360 - val_accuracy: 0.7766 - val_loss: 0.8118
# Epoch 42/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 419ms/step - accuracy: 0.7892 - loss: 0.6240 - val_accuracy: 0.7907 - val_loss: 0.7709
# Epoch 43/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 400ms/step - accuracy: 0.7937 - loss: 0.6008 - val_accuracy: 0.7682 - val_loss: 0.7976
# Epoch 44/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 403ms/step - accuracy: 0.7967 - loss: 0.6050 - val_accuracy: 0.7794 - val_loss: 0.7894
# Epoch 45/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 434ms/step - accuracy: 0.7696 - loss: 0.6545 - val_accuracy: 0.7794 - val_loss: 0.7961
# Epoch 46/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 423ms/step - accuracy: 0.7968 - loss: 0.5879 - val_accuracy: 0.7645 - val_loss: 0.8119
# Epoch 47/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 504ms/step - accuracy: 0.8026 - loss: 0.5790 - val_accuracy: 0.7710 - val_loss: 0.7817
# Epoch 48/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 20s 479ms/step - accuracy: 0.8012 - loss: 0.5665 - val_accuracy: 0.7710 - val_loss: 0.8077
# Epoch 49/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 442ms/step - accuracy: 0.7982 - loss: 0.5689 - val_accuracy: 0.7692 - val_loss: 0.8132
# Epoch 50/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 446ms/step - accuracy: 0.7905 - loss: 0.5775 - val_accuracy: 0.7897 - val_loss: 0.7579
# Training completed and model saved.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# Predicted CAPTCHA: 2b827
